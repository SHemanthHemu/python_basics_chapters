# %%
var1 = 5 # proper identifier declaration

# %%
print(var1)
# Out:
# 5

# %%
def greet(): # proper identifier declaration
    print("hello")

# %%
greet()
# Out:
# hello

# %%
import = 6 # 1. we cannot use python reserved keywords in out identifier decleration
# Out:
#   Cell In[7], line 1
#     import = 6
#            ^
# SyntaxError: invalid syntax

# %%
1val = 7 # 2. we cannot start a identifier with a number
# Out:
#   Cell In[8], line 1
#     1val = 7
#     ^
# SyntaxError: invalid decimal literal

# %%
val@ = 8 # 3. we cannot use special charactors in our identifier decleration
# Out:
#   Cell In[10], line 1
#     val@ = 8 # 3. we cannot use special charactors in our identifier decleration
#          ^
# SyntaxError: invalid syntax
