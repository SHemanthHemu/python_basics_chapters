# %%
import sys 
import keyword 
import operator 
from datetime import datetime 
import os

# %% [markdown]
# ## 1. Key words

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# ## 2. identifiers

# %%
var = 5 # right

# %%
def greet(): # right
    print("hello")

# %%
# 1. identifier can't start with a number but it can contains a number init
1var =6 # wrong
# Out:
#   Cell In[6], line 2
#     1var =6 # wrong
#     ^
# SyntaxError: invalid decimal literal

# %%
var1 = 6 # right

# %%
#2 . identifier can't contain special charactors except _
var@ = 7 # wrong
# Out:
#   Cell In[8], line 2
#     var@ = 7 # wrong
#          ^
# SyntaxError: invalid syntax

# %%
var_ =8 # right

# %%
_var = 6 # right

# %%
print(_var)
# Out:
# 6

# %%
# 3. identifier can't name like python reserved keywords 
def = 6 # wrong
# Out:
#   Cell In[12], line 2
#     def = 6 # wrong
#         ^
# SyntaxError: invalid syntax

# %%
def_1 = 6 # right

# %% [markdown]
# ## 4. Comments

# %%
# single line comment 
# hear var has been assined with value 25
var = 25

# %%
""" this is a multiline comment 
and hear i am printing the value of var
this will print the value of var """ 
print(var)
# Out:
# 25

# %% [markdown]
# ## 5. Statements

# %%
a = 25 # sinfle line statement
print(a)
# Out:
# 25

# %%
b = [1,2,3,5,6]
print(b)
# Out:
# [1, 2, 3, 5, 6]

# %%
a = 25+32+8\
+22\
+10 # multiline statement
print(a)
# Out:
# 97

# %%
b = [1,2, 
     3,4,
     5,6,
     8,9,
     ]
print(b)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9]

# %% [markdown]
# ## 6. Indentation

# %%
p = 10

if p == 10: # correct indentation
    print("abc")
    print("p is equal to 10")
# Out:
# abc
# p is equal to 10

# %%
if p == 10: 
print("p is equal to 10") # incorrect indentation
# Out:
# p is equal to 10

# %%
for i in range(1,5): #correct indentation
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,5): # incorrect indentation
    
print(i)

# %%
for i in range(1,5): print(i) # correct indentation but less readable
# Out:
# 1
# 2
# 3
# 4

# %%
j = 25
for i in range(0,5):
    pass # inside for loop
print(j) # out side the for loop
# Out:
# 25

# %% [markdown]
# ## 7. Docstring

# %%
def square(num):
    '''Squre Function :- this function will take a number and return it's square value'''
    return num**2

# %%
square(4)
# Out:
# 16

# %%
square.__doc__
# Out:
# "Squre Function :- this function will take a number and return it's square value"

# %%
print("hi")

# %%
print.__doc__
# Out:
# 'Prints the values to a stream, or to sys.stdout by default.\n\n  sep\n    string inserted between values, default a space.\n  end\n    string appended after the last value, default a newline.\n  file\n    a file-like object (stream); defaults to the current sys.stdout.\n  flush\n    whether to forcibly flush the stream.'

# %% [markdown]
# ## 8. Variables

# %%
a = 45
b = 30
c = a

# %%
hex(id(a))
# Out:
# '0x7ffdb13c0d58'

# %%
hex(id(c))
# Out:
# '0x7ffdb13c0d58'

# %%
hex(id(b))
# Out:
# '0x7ffdb13c0f38'

# %%
print(f"hi ravi you got incremant of {a} ")
print(f"hi suresh you got incremant of {b} ")
print(f"hi prsad you got incremant of {a} ")
print(f"hi rahul you got incremant of {a} ")
print(f"hi mani you got incremant of {a} ")
# Out:
# hi ravi you got incremant of 45
# hi suresh you got incremant of 30
# hi prsad you got incremant of 45
# hi rahul you got incremant of 45
# hi mani you got incremant of 45

# %%
x = 20

# %%
x = "hi"

# %%
type(x)
# Out:
# str
