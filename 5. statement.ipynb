# %%
a = 25 # sinfle line statement
print(a)
# Out:
# 25

# %%
b = [1,2,3,5,6]
print(b)
# Out:
# [1, 2, 3, 5, 6]

# %%
a = 25+32+8\
+22\
+10 # multiline statement
print(a)
# Out:
# 97

# %%
b = [1,2, 
     3,4,
     5,6,
     8,9,
     ]
print(b)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9]
